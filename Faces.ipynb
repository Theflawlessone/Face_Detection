# %% [markdown]
# <a href="https://colab.research.google.com/github/Theflawlessone/Face_Detection/blob/main/Faces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Dataset

# %%
from google.colab import drive
import pandas as pd
import numpy as np
drive.mount('/content/drive')
data_path = '{UTKface_inthewild}'

# %%
from google.colab import drive

drivepath = "/content/drive/UTKFaceDataset/UTKface_inthewild"
drive.mount(drivepath)
file_path = drivepath + "/part1.tar.gz"
print(filepath)
# df = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-244553334.py in <cell line: 0>()
#       2
#       3 drivepath = "/content/drive/UTKFaceDataset/UTKface_inthewild"
# ----> 4 drive.mount(drivepath)
#       5 file_path = drivepath + "/part1.tar.gz"
#       6 print(filepath)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     198     normed = _os.path.normpath(mountpoint)
# ...

# %% [markdown]
# ## Cleaning Dataset
